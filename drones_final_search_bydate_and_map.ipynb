# %% [markdown]
# # Drone Imagery Search System

# %%
# Install required packages (only needed once)
# !pip install flask pandas
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (3.1.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask) (8.3.2)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.8)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## 1. Database Setup

# %%
import os
import re
from datetime import datetime
import sqlite3
import pandas as pd
from flask import Flask, request, jsonify, render_template_string
from IPython.display import HTML, display
import threading

def setup_database():
    """Create SQLite database and tables if they don't exist"""
    conn = sqlite3.connect("drone_folders.db")
    cursor = conn.cursor()

    # Create tables
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS professional (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT,
        date TEXT,
        folder_path TEXT
    );
    """)

    cursor.execute("""
    CREATE TABLE IF NOT EXISTS personal (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT,
        date TEXT,
        folder_path TEXT
    );
    """)

    # Add coordinates table with explicit creation
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS professional_coordinates (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        professional_name TEXT,
        lat REAL,
        lon REAL,
        sequence INTEGER,
        FOREIGN KEY(professional_name) REFERENCES professional(name)
    );
    """)

    cursor.execute("""
    CREATE TABLE IF NOT EXISTS personal_coordinates (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        personal_name TEXT,
        lat REAL,
        lon REAL,
        sequence INTEGER,
        FOREIGN KEY(personal_name) REFERENCES personal(name)
    );
    """)

    conn.commit()
    conn.close()
    print("Database setup complete - all tables verified")


# Run the setup and display
setup_database()
# Out:
# Database setup complete - all tables verified

# %% [markdown]
# ## 2. Data Import from Google Drive

# %%
from google.colab import drive

def mount_google_drive():
    """Mount Google Drive to access files"""
    drive.mount('/content/drive')
    print("Google Drive mounted")

mount_google_drive()

# mrk files
def extract_lat_lon_mrk(mrk_file):
    """Extract coordinates from MRK file with tab-delimited parsing"""
    coords = []
    try:
        with open(mrk_file, "r") as f:
            for idx, line in enumerate(f):
                # Split on both tabs and commas
                parts = line.replace('\t', ',').split(',')
                parts = [p.strip() for p in parts if p.strip()]

                try:
                    # Find Lat and Lon markers
                    lat_idx = parts.index('Lat') - 1
                    lon_idx = parts.index('Lon') - 1

                    lat = float(parts[lat_idx])
                    lon = float(parts[lon_idx])
                    coords.append((lat, lon, idx))
                except (ValueError, IndexError):
                    continue

    except Exception as e:
        print(f"Error reading {mrk_file}: {e}")
    return coords

# srt files
def extract_lat_lon_srt(srt_file):
    """Extract coordinates from SRT file with tab-delimited parsing"""
    coords = []
    try:
        with open(srt_file, "r") as f:
            for idx, line in enumerate(f):

                if line.startswith("["):

                  # Split on both tabs and commas
                  parts = line.replace('\t', ',').split(',')
                  parts = [p.strip() for p in parts if p.strip()]

                  try:
                      # Find Lat and Lon markers
                      lat_idx = parts.index('[latitude:') + 1
                      lon_idx = parts.index('[longitude:') + 1

                      lat = float(parts[lat_idx])
                      lon = float(parts[lon_idx])
                      coords.append((lat, lon, idx))
                  except (ValueError, IndexError):
                      continue

    except Exception as e:
        print(f"Error reading {srt_file}: {e}")
    return coords

def import_folder_data(folder_path):
    """Import folder names and process MRK files"""
    conn = sqlite3.connect("drone_folders.db")
    cursor = conn.cursor()

    inserted_pro = 0
    inserted_coords = 0
    inserted_per = 0

    # looks at each month in year
    for month in os.listdir(folder_path):
        month_path = os.path.join(folder_path, month)
        if not os.path.isdir(month_path):
            continue

        # flight in each month
        for name in os.listdir(month_path):
          full_path = os.path.join(month_path, name)
          if not os.path.isdir(full_path):
            continue

          # PROFESSIONAL FILES
          if name.startswith("DJI_") and "_" in name:
              try:
                  parts = name.split("_")
                  raw_date = parts[1]  # e.g. '202410171502'
                  parsed_date = datetime.strptime(raw_date, "%Y%m%d%H%M").strftime('%Y-%m-%d')

                  # Check if already exists
                  cursor.execute("SELECT 1 FROM professional WHERE name = ?", (name,))
                  if cursor.fetchone() is None:
                      cursor.execute("""
                          INSERT INTO professional (name, date, folder_path)
                          VALUES (?, ?, ?)
                      """, (name, parsed_date, full_path))
                      inserted_pro += 1
                      print(f"✅ Inserted professional folder: {name}")

                  # Process MRK file regardless of whether it's new
                  mrk_files = [f for f in os.listdir(full_path) if f.lower().endswith(".mrk")]
                  if mrk_files:
                      # Clear existing coordinates for this flight (if any)
                      cursor.execute("""
                          DELETE FROM professional_coordinates
                          WHERE professional_name = ?
                      """, (name,))

                      # Process each MRK file found
                      for mrk_file in mrk_files:
                          mrk_path = os.path.join(full_path, mrk_file)
                          coords = extract_lat_lon_mrk(mrk_path)
                          for seq, (lat, lon, _) in enumerate(coords):
                              cursor.execute("""
                                  INSERT INTO professional_coordinates
                                  (professional_name, lat, lon, sequence)
                                  VALUES (?, ?, ?, ?)
                              """, (name, lat, lon, seq))
                          inserted_coords += len(coords)
                          print(f"  ↳ Processed {len(coords)} coordinates from {mrk_file}")
                  else:
                      print(f"  ↳ No MRK files found in {name}")

              except Exception as e:
                  print(f"❌ Error processing {name}: {str(e)}")

          # PERSONAL FILES
          else:
            # file: mm-ddLocation
            if name.count('.') == 1:
              try:
                  date_part = name.split('.')[0]
                  day_and_rest = name.split('.')[1]

                  # check if day is two digits or 1 digit
                  if day_and_rest[1].isdigit():
                    day = day_and_rest[:2]
                    rest = day_and_rest[2:]
                  else:
                    day = day_and_rest[:1]
                    rest = day_and_rest[1:]

                  match = re.search(r'(20\d{2})', folder_path)
                  year = match.group(1) if match else "0000" # assumes all data is from 2024
                  parsed_date = datetime.strptime(f"{year}-{date_part}-{day}", "%Y-%m-%d").strftime('%Y-%m-%d')

                  cursor.execute("SELECT 1 FROM personal WHERE name = ?", (name,))
                  if cursor.fetchone() is None:
                      cursor.execute("INSERT INTO personal (name, date, folder_path) VALUES (?, ?, ?)",
                                  (name, parsed_date, full_path))
                      inserted_per += 1
                      print(f"✅ Inserted personal folder: {name}")

                  # process SRT file
                  srt_files = [f for f in os.listdir(full_path) if f.lower().endswith(".srt")]
                  if srt_files:
                      # Clear existing coordinates for this flight (if any)
                      cursor.execute("""
                          DELETE FROM personal_coordinates
                          WHERE personal_name = ?
                      """, (name,))

                      # Process each SRT file found
                      for srt_file in srt_files:
                          srt_path = os.path.join(full_path, srt_file)
                          coords = extract_lat_lon_srt(srt_path)
                          for seq, (lat, lon, _) in enumerate(coords):
                              cursor.execute("""
                                  INSERT INTO personal_coordinates
                                  (personal_name, lat, lon, sequence)
                                  VALUES (?, ?, ?, ?)
                              """, (name, lat, lon, seq))
                          inserted_coords += len(coords)
                          print(f"  ↳ Processed {len(coords)} coordinates from {srt_file}")
                  else:
                      print(f"  ↳ No SRT files found in {name}")



              except Exception as e:
                  print(f"❌ Failed to parse personal folder {name}: {e}")



            else:
              print(f"⚠️ Unrecognized format: {name}")

    conn.commit()
    conn.close()

# Usage: (uncomment and modify path as needed)
folder_path = '/content/drive/MyDrive/csc230-drones/2025'
import_folder_data(folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted
#   ↳ No SRT files found in 2.24GeothermalProgressPhotos
#   ↳ Processed 257 coordinates from DJI_202502281519_003_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ No MRK files found in DJI_202502281519_004_PondSnow
#   ↳ Processed 257 coordinates from DJI_202503111445_008_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 1 coordinates from DJI_202503111445_009_Timestamp.MRK
#   ↳ No SRT files found in 3.11GeothermalUnorganized
#   ↳ No SRT files found in 3.12UpperRobertsMeadow
#   ↳ No SRT files found in 3.12_CEEDS360Cam_PowerPlantTour
#   ↳ Processed 50 coordinates from DJI_202503191209_015_ChapinLawn_Timestamp.MRK
#   ↳ Processed 45 coordinates from DJI_202503191209_014_BurtonLawn_Timestamp.MRK
#   ↳ Processed 76 coordinates from DJI_202503191254_018_ParadiseQuad_Timestamp.MRK
#   ↳ Processed 61 coordinates from DJI_202503191238_017_DavisLawn_Timestamp.MRK
#   ↳ Processed 62 coordinates from DJI_202503191209_016_SeelyeLawn_Timestamp.MRK
#   ↳ No SRT files found in 3.25GeothermalOrganized
#   ↳ Processed 0 coordinates from AthleticFieldBoreField_DJI_20250311132722_0013_V.SRT
#   ↳ Processed 0 coordinates from AthleticFieldBoreField_DJI_20250311132750_0014_V.SRT
#   ↳ Processed 0 coordinates from NeilsonSouth_DJI_20250311134101_0003_V.SRT
#   ↳ No SRT files found in 3.27ENV201202
#   ↳ No SRT files found in 3.31UpperRobertsMeadowAerialImagery
#   ↳ No SRT files found in 3.10AllFarmersOrganized
#   ↳ Processed 257 coordinates from DJI_202501101056_015_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202501101056_016_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ No SRT files found in 1.10PondGate_PostSedRedOverviewImages
#   ↳ Processed 257 coordinates from DJI_202501171311_018_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ No SRT files found in 1.10GeothermalMedia_GreenStCircle_AthleticFields_CollegeLane
#   ↳ Processed 0 coordinates from DJI_20250124162108_0001_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162132_0002_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162143_0003_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162204_0004_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162219_0005_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162239_0006_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162303_0007_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162325_0008_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162344_0009_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162405_0010_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162416_0011_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162452_0012_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162504_0013_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162601_0014_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162632_0015_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162652_0016_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162729_0017_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162751_0018_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162807_0019_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162822_0020_V.SRT
#   ↳ Processed 0 coordinates from DJI_20250124162841_0021_V.SRT
#   ↳ Processed 257 coordinates from DJI_202501241612_019_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 406 coordinates from DJI_202501281427_021_GFNMain_Timestamp.MRK
#   ↳ Processed 996 coordinates from DJI_202501281503_001_GFN2_Timestamp.MRK
#   ↳ Processed 709 coordinates from DJI_202501281524_002_GFN2_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202501310957_001_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ No SRT files found in 1.10SolarPanelsHVAC
# ⚠️ Unrecognized format: GFNProcessedData
#   ↳ No SRT files found in 1.9ITTSolarPanels+ParkingLot
#   ↳ Processed 257 coordinates from DJI_202504101315_024_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ No MRK files found in DJI_202504101315_025
#   ↳ No SRT files found in 4.10GeothermalSites
#   ↳ Processed 257 coordinates from DJI_202504241330_002_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ No SRT files found in 4.24GeothermalSites
#   ↳ No SRT files found in 4.26QueerScience
#   ↳ No SRT files found in 4.19Poetry+SmithArts
#   ↳ No SRT files found in 5.7CampusConstructionUpdates
#   ↳ Processed 211 coordinates from DJI_202505121016_033_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 202 coordinates from DJI_202505121016_032_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 567 coordinates from DJI_202505121058_035_MFSGoats_Timestamp.MRK
#   ↳ No SRT files found in 5.12MacLeish
#   ↳ No SRT files found in 5.17Mags
#   ↳ Processed 20 coordinates from DJI_202506051108_038_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202506051108_037_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 12 coordinates from DJI_202506051137_039_Timestamp.MRK
#   ↳ Processed 567 coordinates from DJI_202506161341_001_MFSGoats_Timestamp.MRK
#   ↳ Processed 211 coordinates from DJI_202506161341_002_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202506161453_003_ParadisePondBaseWithLeg_Timestamp.MRK
# ⚠️ Unrecognized format: 16JuneGeothermal
#   ↳ Processed 8 coordinates from DJI_202506241528_007_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202506241528_008_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202507111141_011_ParadisePondBaseWithLeg_Timestamp.MRK
# ⚠️ Unrecognized format: 11JulyGeothermal
#   ↳ Processed 24 coordinates from DJI_202507231143_016_Timestamp.MRK
#   ↳ Processed 145 coordinates from DJI_202507231127_015_BombyxFull_Timestamp.MRK
#   ↳ Processed 177 coordinates from DJI_202507231127_014_Bombyx1_Timestamp.MRK
# ⚠️ Unrecognized format: 23JulyBombyx
#   ↳ Processed 566 coordinates from DJI_202507281643_018_MFSGoats_Timestamp.MRK
#   ↳ No MRK files found in DJI_202507281643_020
#   ↳ Processed 10 coordinates from DJI_202507291006_001_Timestamp.MRK
#   ↳ Processed 1 coordinates from DJI_202507291020_004_Timestamp.MRK
#   ↳ Processed 10 coordinates from DJI_202507291020_002_Timestamp.MRK
#   ↳ Processed 4 coordinates from DJI_202507291037_005_Timestamp.MRK
# ⚠️ Unrecognized format: 29JulyGeothermal
#   ↳ Processed 257 coordinates from DJI_202507291020_003_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 211 coordinates from DJI_202507281643_019_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 11 coordinates from DJI_202508040939_006_Timestamp.MRK
#   ↳ Processed 10 coordinates from DJI_202508040949_007_Timestamp.MRK
# ⚠️ Unrecognized format: 4August-GeothermalPhotos
# ⚠️ Unrecognized format: 7August-GeothermalPiping
#   ↳ Processed 257 coordinates from DJI_202508221236_008_ParadisePondBaseWithLeg_Timestamp.MRK
# ⚠️ Unrecognized format: 22August-GeothermalPhotos
#   ↳ Processed 101 coordinates from DJI_202508281557_009_CC_Timestamp.MRK
#   ↳ No SRT files found in 9.8RugbyFieldPoles
#   ↳ No SRT files found in 9.8TennisCourts
#   ↳ No SRT files found in 9.12Etta
#   ↳ No SRT files found in 9.12Hanna
#   ↳ Processed 0 coordinates from DJI_0138.SRT
#   ↳ No SRT files found in 9.12Sylvie
#   ↳ Processed 0 coordinates from DJI_0164.SRT
#   ↳ Processed 0 coordinates from DJI_0165.SRT
#   ↳ No SRT files found in 9.17Leah
#   ↳ Processed 211 coordinates from DJI_202509171449_012_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202509181018_013_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ No SRT files found in 9.18GeothermalConstructionProgress
#   ↳ Processed 15 coordinates from DJI_202509230858_016_Timestamp.MRK
#   ↳ Processed 72 coordinates from DJI_202509230858_015_CC_Timestamp.MRK
#   ↳ Processed 211 coordinates from DJI_202510011444_017_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 256 coordinates from DJI_202510071138_018_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 0 coordinates from DJI_0210.SRT
#   ↳ Processed 0 coordinates from DJI_0218.SRT
#   ↳ Processed 0 coordinates from DJI_0220.SRT
#   ↳ Processed 0 coordinates from DJI_0205.SRT
#   ↳ Processed 0 coordinates from DJI_0225.SRT
#   ↳ Processed 0 coordinates from DJI_0224.SRT
#   ↳ Processed 0 coordinates from DJI_0223.SRT
#   ↳ Processed 0 coordinates from DJI_0222.SRT
#   ↳ Processed 0 coordinates from DJI_0211.SRT
#   ↳ Processed 0 coordinates from DJI_0221.SRT
#   ↳ Processed 0 coordinates from DJI_0212.SRT
#   ↳ Processed 0 coordinates from DJI_0219.SRT
#   ↳ Processed 0 coordinates from DJI_0206.SRT
#   ↳ Processed 211 coordinates from DJI_202510081416_019_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 566 coordinates from DJI_202510081432_020_MFSGoats_Timestamp.MRK
#   ↳ No SRT files found in 10.10RockPark
#   ↳ Processed 211 coordinates from DJI_202510221409_021_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 1 coordinates from DJI_202510221409_022_Timestamp.MRK
#   ↳ Processed 564 coordinates from DJI_202510221422_023_MFSGoats_Timestamp.MRK
#   ↳ Processed 414 coordinates from DJI_202510291422_025_MFSGoats_Timestamp.MRK
#   ↳ Processed 211 coordinates from DJI_202510291422_024_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 6 coordinates from DJI_202511041346_002_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202511041346_001_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202511051108_003_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 104 coordinates from DJI_202511051108_004_Timestamp.MRK
#   ↳ No SRT files found in 11.18GeothermalPhotos
#   ↳ Processed 257 coordinates from DJI_202511211454_006_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 142 coordinates from DJI_202511240959_007_BombyxFull_Timestamp.MRK
#   ↳ Processed 4 coordinates from DJI_202511240959_008_Timestamp.MRK
#   ↳ Processed 169 coordinates from DJI_202511241359_009_MFS-snakeRestoration_Timestamp.MRK
#   ↳ Processed 257 coordinates from DJI_202512181311_010_ParadisePondBaseWithLeg_Timestamp.MRK
#   ↳ Processed 92 coordinates from DJI_202512181311_011_Create-Area-Route1_Timestamp.MRK

# %% [markdown]
# ## 3. Run the Application

# %%
from flask import Flask, request, jsonify, render_template_string
from google.colab import output
from IPython.display import HTML, display
import threading
import sqlite3
from datetime import datetime
import time
import socket
from flask import send_from_directory
import os

app = Flask(__name__)

# Database connection
def get_db_connection():
    conn = sqlite3.connect("drone_folders.db")
    conn.row_factory = sqlite3.Row
    return conn

# HTML template
HTML_TEMPLATE = """
<!DOCTYPE html>
<html>
<head>
    <title>Drone Imagery Search</title>
    <style>
        body { font-family: Arial, sans-serif; padding: 20px; }
        .search-form { background: #f5f5f5; padding: 20px; border-radius: 8px; margin-bottom: 20px; }
        .form-group { margin-bottom: 15px; }
        label { display: inline-block; width: 100px; font-weight: bold; }
        input, select { padding: 8px; border: 1px solid #ddd; border-radius: 4px; }
        button { background: #4CAF50; color: white; padding: 10px 15px; border: none; border-radius: 4px; cursor: pointer; }
        button:hover { background: #45a049; }
        .results { margin-top: 20px; }
        .result-item { border: 1px solid #ddd; padding: 15px; margin-bottom: 10px; border-radius: 4px; }
        .result-type { font-weight: bold; color: #fff; padding: 3px 8px; border-radius: 4px; }
        .professional { background: #2196F3; }
        .personal { background: #4CAF50; }
        .error { color: red; margin-top: 10px; }
    </style>
</head>
<body>
    <h1>Drone Imagery Search</h1>
    <div class="search-form">
        <form id="searchForm">
            <div class="form-group">
                <label for="date_from">From Date:</label>
                <input type="date" id="date_from" name="date_from" required>
            </div>
            <div class="form-group">
                <label for="date_to">To Date:</label>
                <input type="date" id="date_to" name="date_to" required>
            </div>
            <div class="form-group">
                <label for="imagery_type">Type:</label>
                <select id="imagery_type" name="imagery_type">
                    <option value="all">All</option>
                    <option value="professional">Professional</option>
                    <option value="personal">Personal</option>
                </select>
            </div>
            <button type="submit">Search</button>
        </form>
    </div>
    <div id="results"></div>
    <script>
        document.getElementById('searchForm').addEventListener('submit', async (e) => {
            e.preventDefault();
            const resultsDiv = document.getElementById('results');
            resultsDiv.innerHTML = '<p>Searching...</p>';

            const formData = new FormData(e.target);
            const params = new URLSearchParams(formData);

            try {
                const response = await fetch('/search?' + params.toString());
                if (!response.ok) {
                    throw new Error(`HTTP error! status: ${response.status}`);
                }
                const data = await response.json();

                if (data.error) {
                    resultsDiv.innerHTML = `<div class="error">${data.error}</div>`;
                    return;
                }

                if (data.results.length === 0) {
                    resultsDiv.innerHTML = '<div>No results found for the selected criteria</div>';
                    return;
                }

                let html = '';
                data.results.forEach(item => {
                    html += `
                        <div class="result-item">
                            <h3>${item.name}</h3>
                            <p>Date: ${item.date}</p>
                            <p>Type: <span class="result-type ${item.type}">${item.type}</span></p>
                            <p>Path: ${item.file_path}</p>
                        </div>
                    `;
                });

                resultsDiv.innerHTML = html;
            } catch (error) {
                console.error('Error:', error);
                resultsDiv.innerHTML = '<div class="error">Error fetching results. Check console for details.</div>';
            }
        });
    </script>
</body>
</html>
"""

# Flask routes
@app.route('/')
def index():
    return render_template_string(HTML_TEMPLATE)

@app.route('/search')
def search():
    date_from = request.args.get('date_from')
    date_to = request.args.get('date_to')
    imagery_type = request.args.get('imagery_type', 'all')

    if not date_from or not date_to:
        return jsonify({'error': 'Both date ranges are required'}), 400

    try:
        # Convert dates to datetime.date objects for proper comparison
        date_from = datetime.strptime(date_from, '%Y-%m-%d').date()
        date_to = datetime.strptime(date_to, '%Y-%m-%d').date()
    except ValueError:
        return jsonify({'error': 'Invalid date format. Use YYYY-MM-DD'}), 400

    conn = get_db_connection()
    results = []

    try:
        if imagery_type in ['all', 'professional']:
            professional = conn.execute("""
                SELECT
                    name,
                    date,
                    folder_path as file_path,
                    'professional' as type
                FROM professional
                WHERE date BETWEEN ? AND ?
                ORDER BY date
            """, (date_from, date_to))
            results.extend([dict(row) for row in professional.fetchall()])

        if imagery_type in ['all', 'personal']:
            personal = conn.execute("""
                SELECT
                    name,
                    date,
                    folder_path as file_path,
                    'personal' as type
                FROM personal
                WHERE date BETWEEN ? AND ?
                ORDER BY date
            """, (date_from, date_to))
            results.extend([dict(row) for row in personal.fetchall()])

        return jsonify({'results': results})

    except Exception as e:
        return jsonify({'error': str(e)}), 500
    finally:
        conn.close()

def flight_map():
    """Render the flight map page"""
    return render_template_string("""
    <!DOCTYPE html>
    <html>
    <head>
        <title>Flight Map</title>
        <meta charset="utf-8" />
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <link rel="stylesheet" href="https://unpkg.com/leaflet@1.9.4/dist/leaflet.css" />
        <style>
            #map { height: 600px; }
        </style>
    </head>
    <body>
        <h1>Drone Flight Paths</h1>
        <div id="map"></div>
        <script src="https://unpkg.com/leaflet@1.9.4/dist/leaflet.js"></script>
        <script>
            const map = L.map('map').setView([42.3251, -72.6412], 15);
            L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
                maxZoom: 18,
            }).addTo(map);

            fetch('/api/flights')
                .then(response => response.json())
                .then(data => {
                    for (const [name, coords] of Object.entries(data)) {
                        const polyline = L.polyline(coords, {color: 'blue'}).addTo(map);
                        polyline.bindPopup(`<b>${name}</b>`);
                    }
                })
                .catch(err => console.error('Error loading flight data:', err));
        </script>
    </body>
    </html>
    """)

@app.route('/map')
def show_map():
    """Render the flight map page"""
    return render_template_string("""
    <!DOCTYPE html>
    <html>
    <head>
        <title>Flight Map</title>
        <meta charset="utf-8" />
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <link rel="stylesheet" href="https://unpkg.com/leaflet@1.9.4/dist/leaflet.css" />
        <style>
            body { padding: 20px; }
            #map { height: 600px; margin-top: 20px; }
            .back-link { margin-bottom: 20px; display: inline-block; }
        </style>
    </head>
    <body>
        <a class="back-link" href="/">← Back to Search</a>
        <h1>Drone Flight Paths</h1>
        <div id="map"></div>

        <script src="https://unpkg.com/leaflet@1.9.4/dist/leaflet.js"></script>
        <script>
            const map = L.map('map').setView([42.3251, -72.6412], 15);
            L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
                maxZoom: 18,
                attribution: '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'
            }).addTo(map);

            fetch('/api/flights')
                .then(response => {
                    if (!response.ok) {
                        throw new Error('Network response was not ok');
                    }
                    return response.json();
                })
                .then(data => {
                    if (Object.keys(data).length === 0) {
                        const infoDiv = document.createElement('div');
                        infoDiv.innerHTML = '<p>No flight path data available</p>';
                        document.body.appendChild(infoDiv);
                        return;
                    }

                    for (const [name, coords] of Object.entries(data)) {
                        if (coords.length > 0) {
                            const polyline = L.polyline(coords, {color: 'blue'}).addTo(map);
                            polyline.bindPopup(`<b>${name}</b>`);
                            // Auto-fit the map to the bounds of all polylines
                            map.fitBounds(polyline.getBounds());
                        }
                    }
                })
                .catch(err => {
                    console.error('Error loading flight data:', err);
                    const errorDiv = document.createElement('div');
                    errorDiv.innerHTML = `<p style="color:red">Error loading flight data: ${err.message}</p>`;
                    document.body.appendChild(errorDiv);
                });
        </script>
    </body>
    </html>
    """)


@app.route('/api/flights')
def get_flights():
    """API endpoint to get flight path data"""
    conn = get_db_connection()
    try:
        # Get all professional flights with coordinates
        flights = conn.execute("""
            SELECT p.name, pc.lat, pc.lon, pc.sequence
            FROM professional p
            JOIN professional_coordinates pc ON p.name = pc.professional_name
            ORDER BY p.name, pc.sequence
        """).fetchall()

        # Group coordinates by flight name
        flight_data = {}
        for row in flights:
            name = row['name']
            if name not in flight_data:
                flight_data[name] = []
            flight_data[name].append([row['lat'], row['lon']])

        return jsonify(flight_data)
    except Exception as e:
        return jsonify({'error': str(e)}), 500
    finally:
        conn.close()

# Shutdown function
def shutdown_server():
    func = request.environ.get('werkzeug.server.shutdown')
    if func is None:
        raise RuntimeError('Not running with the Werkzeug Server')
    func()

@app.route('/shutdown', methods=['POST'])
def shutdown():
    shutdown_server()
    return 'Server shutting down...'


def find_free_port():
    """Find a free port starting from 9000"""
    port = 9000
    while True:
        try:
            with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
                s.bind(('0.0.0.0', port))
                return port
        except OSError:
            port += 1

def run_flask(port):
    app.run(host='0.0.0.0', port=port, debug=False, use_reloader=False)

# Find an available port
port = find_free_port()

# Start Flask in a thread
flask_thread = threading.Thread(target=run_flask, args=(port,))
flask_thread.daemon = True
flask_thread.start()

# Wait for server to start
time.sleep(2)

# Get proxy URL
proxy_url = output.eval_js(f'google.colab.kernel.proxyPort({port})')

# Display interface with FIXED shutdown button
display(HTML(f"""
    <h2>Drone Imagery Search Interface</h2>
    <div style="margin-bottom: 15px;">
        <a href="{proxy_url}" target="_blank" style="margin-right: 15px;">Open Search</a>
        <a href="{proxy_url}/map" target="_blank">Open Flight Map</a>
    </div>
    <iframe src="{proxy_url}" width="100%" height="600px"></iframe>
    <p>To stop the server: <button onclick="fetch('{proxy_url}/shutdown', {{'method': 'POST'}})">Shutdown</button></p>
    <p>Running on port: {port}</p>
"""))
print(f"If the interface doesn't load, visit: {proxy_url}")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:9004
#  * Running on http://172.28.0.12:9004
# INFO:werkzeug:Press CTRL+C to quit
#     <h2>Drone Imagery Search Interface</h2>
#     <div style="margin-bottom: 15px;">
#         <a href="https://9004-m-s-kkb-ase1a2-1owcic5xhwocb-a.asia-east1-2.prod.colab.dev" target="_blank" style="margin-right: 15px;">Open Search</a>
#         <a href="https://9004-m-s-kkb-ase1a2-1owcic5xhwocb-a.asia-east1-2.prod.colab.dev/map" target="_blank">Open Flight Map</a>
#     </div>
#     <iframe src="https://9004-m-s-kkb-ase1a2-1owcic5xhwocb-a.asia-east1-2.prod.colab.dev" width="100%" height="600px"></iframe>
#     <p>To stop the server: <button onclick="fetch('https://9004-m-s-kkb-ase1a2-1owcic5xhwocb-a.asia-east1-2.prod.colab.dev/shutdown', {'method': 'POST'})">Shutdown</button></p>
#     <p>Running on port: 9004</p>
# If the interface doesn't load, visit: https://9004-m-s-kkb-ase1a2-1owcic5xhwocb-a.asia-east1-2.prod.colab.dev

# %% [markdown]
# ## 4. View database content (for debugging purposes)

# %%
def show_database_contents():
    """Display database contents for verification"""
    # First ensure tables exist
    setup_database()

    conn = sqlite3.connect("drone_folders.db")

    print("\nAll tables in database:")
    tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", conn)
    display(tables.reset_index(drop=True))  # Add reset_index() to avoid reference issues

    print("\nProfessional table (first 10 entries):")
    df_pro = pd.read_sql_query("SELECT * FROM professional LIMIT 10", conn)
    display(df_pro.reset_index(drop=True))

    print("\nPersonal table (first 10 entries):")
    df_per = pd.read_sql_query("SELECT * FROM personal LIMIT 10", conn)
    display(df_per.reset_index(drop=True))

    try:
        print("\nProfessional_coordinates table status:")
        # First check if table has any data
        count = pd.read_sql_query("SELECT COUNT(*) as count FROM professional_coordinates", conn)
        display(count)

        if count.iloc[0]['count'] > 0:
            print("\nSample coordinate data (first 20 points):")
            df_coords = pd.read_sql_query("""
                SELECT
                    pc.id,
                    pc.professional_name,
                    p.date,
                    pc.lat,
                    pc.lon,
                    pc.sequence
                FROM professional_coordinates pc
                LEFT JOIN professional p ON pc.professional_name = p.name
                ORDER BY pc.professional_name, pc.sequence
                LIMIT 20
            """, conn)
            display(df_coords.reset_index(drop=True))

            print("\nFlights with coordinate data:")
            df_counts = pd.read_sql_query("""
                SELECT
                    professional_name,
                    COUNT(*) as point_count
                FROM professional_coordinates
                GROUP BY professional_name
                ORDER BY professional_name
            """, conn)
            display(df_counts.reset_index(drop=True))
        else:
            print("The professional_coordinates table is empty.")
            print("\nTo populate it, you need to:")
            print("1. Ensure your professional folders contain .MRK files")
            print("2. Re-run the import_folder_data() function")
            print("3. Verify the MRK files contain coordinate data in the format:")
            print("   LATITUDE,Lat,LONGITUDE,Lon,...")

    except Exception as e:
        print(f"\nError accessing professional_coordinates table: {str(e)}")
        print("\nTry these troubleshooting steps:")
        print("1. Run setup_database() to ensure tables exist")
        print("2. Check if the table exists with:")
        print("   pd.read_sql_query(\"SELECT name FROM sqlite_master WHERE type='table' AND name='professional_coordinates'\", conn)")

    conn.close()

# Run the display
show_database_contents()
# Out:
# Database setup complete - all tables verified
#
# All tables in database:
#                        name
# 0              professional
# 1           sqlite_sequence
# 2                  personal
# 3  professional_coordinates
# 4      personal_coordinates
# Professional table (first 10 entries):
#    id                                          name        date  \
# 0   1  DJI_202502281519_003_ParadisePondBaseWithLeg  2025-02-28
# 1   2                 DJI_202502281519_004_PondSnow  2025-02-28
# 2   3  DJI_202503111445_008_ParadisePondBaseWithLeg  2025-03-11
# 3   4                          DJI_202503111445_009  2025-03-11
# 4   5               DJI_202503191209_015_ChapinLawn  2025-03-19
# 5   6               DJI_202503191209_014_BurtonLawn  2025-03-19
# 6   7             DJI_202503191254_018_ParadiseQuad  2025-03-19
# 7   8                DJI_202503191238_017_DavisLawn  2025-03-19
# 8   9               DJI_202503191209_016_SeelyeLawn  2025-03-19
# 9  10  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10
#
#                                          folder_path
# 0  /content/drive/MyDrive/csc230-drones/2025/2-Fe...
# 1  /content/drive/MyDrive/csc230-drones/2025/2-Fe...
# 2  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 3  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 4  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 5  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 6  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 7  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 8  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 9  /content/drive/MyDrive/csc230-drones/2025/1-Ja...
# Personal table (first 10 entries):
#    id                                   name        date  \
# 0   1           2.24GeothermalProgressPhotos  2025-02-24
# 1   2              3.11GeothermalUnorganized  2025-03-11
# 2   3                 3.12UpperRobertsMeadow  2025-03-12
# 3   4        3.12_CEEDS360Cam_PowerPlantTour  2025-03-12
# 4   5                3.25GeothermalOrganized  2025-03-25
# 5   6                3.11GeothermalOrganized  2025-03-11
# 6   7                          3.27ENV201202  2025-03-27
# 7   8    3.31UpperRobertsMeadowAerialImagery  2025-03-31
# 8   9                3.10AllFarmersOrganized  2025-03-10
# 9  10  1.10PondGate_PostSedRedOverviewImages  2025-01-10
#
#                                          folder_path
# 0  /content/drive/MyDrive/csc230-drones/2025/2-Fe...
# 1  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 2  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 3  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 4  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 5  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 6  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 7  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 8  /content/drive/MyDrive/csc230-drones/2025/3-Ma...
# 9  /content/drive/MyDrive/csc230-drones/2025/1-Ja...
# Professional_coordinates table status:
#    count
# 0  14074
# Sample coordinate data (first 20 points):
#      id                             professional_name        date        lat  \
# 0   810  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.319501
# 1   811  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.319370
# 2   812  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.319251
# 3   813  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.319131
# 4   814  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.319011
# 5   815  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318895
# 6   816  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318779
# 7   817  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318663
# 8   818  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318546
# 9   819  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318430
# 10  820  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318313
# 11  821  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318197
# 12  822  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.318080
# 13  823  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.317963
# 14  824  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.317846
# 15  825  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.317731
# 16  826  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.317616
# 17  827  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.317499
# 18  828  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.317384
# 19  829  DJI_202501101056_015_ParadisePondBaseWithLeg  2025-01-10  42.317349
#
#           lon  sequence
# 0  -72.641382         0
# 1  -72.641379         1
# 2  -72.641376         2
# 3  -72.641373         3
# 4  -72.641370         4
# 5  -72.641366         5
# 6  -72.641364         6
# 7  -72.641362         7
# 8  -72.641359         8
# 9  -72.641356         9
# 10 -72.641353        10
# 11 -72.641350        11
# 12 -72.641348        12
# 13 -72.641345        13
# 14 -72.641341        14
# 15 -72.641338        15
# 16 -72.641335        16
# 17 -72.641333        17
# 18 -72.641349        18
# 19 -72.641463        19
# Flights with coordinate data:
#                                     professional_name  point_count
# 0        DJI_202501101056_015_ParadisePondBaseWithLeg          257
# 1   DJI_202501101056_016_ParadisePondBaseWithLeg_U...          257
# 2        DJI_202501171311_018_ParadisePondBaseWithLeg          257
# 3        DJI_202501241612_019_ParadisePondBaseWithLeg          257
# 4                        DJI_202501281427_021_GFNMain          406
# ..                                                ...          ...
# 62                    DJI_202511240959_007_BombyxFull          142
# 63                               DJI_202511240959_008            4
# 64          DJI_202511241359_009_MFS-snakeRestoration          169
# 65       DJI_202512181311_010_ParadisePondBaseWithLeg          257
# 66                 DJI_202512181311_011_McCartneyHall           92
#
# [67 rows x 2 columns]
